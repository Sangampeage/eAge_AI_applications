# %%
from ultralytics import YOLO

model = YOLO("yolo12n.pt")

def run_object_detection(image_path):
    results = model(image_path)
    return results[0].plot()
# Out:
# image 1/1 c:\Users\sanga\OneDrive\Desktop\My space\Projects\combined\Object detection 2.0\office_test_image4.jpg: 640x480 1 chair, 179.8ms
# Speed: 8.0ms preprocess, 179.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# saved detection_result.jpg
